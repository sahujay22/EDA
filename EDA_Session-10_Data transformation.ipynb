# %% [markdown]
# - Converting skewed distribution to Normal distribution
#
# - All maths developed by assumption as data follows Normal distribution
#
#     - log transformation
#
#     - Reciprocal transformation
#
#     - sqrt transformation
#
#     - exponential transformation
#
#     - box-cox transformation
#
#     - yeo-jhanosn transformation

# %% [markdown]
# $Step-1$:
#
# **Read the packages**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $Step-2$:
#
# **Read the data**

# %%
data=np.random.exponential(size=10000)
# we are taking a random values from exponential distribution
# 1000 samples we are taking

# %%
data[:10]
# Out:
# array([1.25476853, 2.71283859, 0.37447871, 1.55279393, 0.52031753,
#        0.43361373, 1.31110112, 0.47791984, 0.17054248, 0.13494592])

# %%
plt.hist(data,bins=40,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# $Step-3:$:
#
# **Log transformation**
#
# - np.log represents natural logorithm
#
# - natural logorithm means base e
#
# - exponential will multiply with log base e
#
# - Natural logorithms will works postive data
#
# - log transformation will remove the skew
#
# - It will not convert into Normal distribution

# %%
log_data=np.log(data)
plt.hist(log_data,bins=40,label='Log transformation')
plt.legend()
plt.show()

# %%
log_data
# Out:
# array([ 0.22695112,  0.99799554, -0.98222033, ..., -3.60426668,
#        -0.43353937, -0.2724841 ])

# %%
plt.subplot(1,2,1).hist(data,bins=40)
plt.subplot(1,2,2).hist(log_data,bins=40)
plt.show()

# %%
log_log_data=np.log(log_data)
plt.hist(log_log_data,bins=40,label='Log transformation')
plt.legend()
plt.show()
# Out:
# C:\Users\jayan\AppData\Local\Temp\ipykernel_7764\4251579950.py:1: RuntimeWarning: invalid value encountered in log
#   log_log_data=np.log(log_data)

# %% [markdown]
# $Step-4$:
#
# **Reciprocal Transformation**
#
# - If data has zero , it will fail

# %%
print(data[:5])
print(1/data[:5])
# Out:
# [1.25476853 2.71283859 0.37447871 1.55279393 0.52031753]
# [0.79695974 0.36861758 2.67037877 0.64400045 1.92190333]

# %%
rec_data=1/data
plt.hist(rec_data,bins=40,label='Reciprocal transformation')
plt.legend()
plt.show()

# %% [markdown]
# $Step-5$:
#
# **Square root transformation**

# %%
sqrt_data=np.sqrt(data)
plt.hist(sqrt_data,bins=40,label='Square root Transformation')
plt.show()

# %%
a=(10,20)
b=[(1,2),(6,7),(8,9)]

# distance between two points

# %% [markdown]
# **Power Transformer**
#
# it is in sklearn.preprocessing
#
# method argument
#
# box-cox
#
# ye-jhonson
